# %%
import os

os.environ["PYSPARK_PYTHON"] = r"C:\Users\Lenovo\.conda\envs\pyspark310\python.exe"
os.environ["PYSPARK_DRIVER_PYTHON"] = r"C:\Users\Lenovo\.conda\envs\pyspark310\python.exe"

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Test") \
    .master("local[*]") \
    .getOrCreate()

# %%
# Print Spark Web UI URL
print("\nSpark Web UI running at:")
print(spark.sparkContext.uiWebUrl, "\n")
# Out:
# Spark Web UI running at:
# http://host.docker.internal:4040

# %% [markdown]
# RDD Actions

# %%
rdd = spark.sparkContext.parallelize([1,2,3,4,5])
print(rdd.count())
# Out:
# 5

# %%
data=[("Alice",27),("Bob",33),("Charlie",24),("Alice",32)]
rdd=spark.sparkContext.parallelize(data)

# %%
#print all elements of data
print(rdd.collect())
# Out:
# [('Alice', 27), ('Bob', 33), ('Charlie', 24), ('Alice', 32)]

# %%
first=rdd.first()
print(first)
# Out:
# ('Alice', 27)

# %%
taken_elements=rdd.take(2)
print(taken_elements)
# Out:
# [('Alice', 27), ('Bob', 33)]

# %%
for x in rdd.collect():
    print(x)
# Out:
# ('Alice', 27)
# ('Bob', 33)
# ('Charlie', 24)
# ('Alice', 32)

# %% [markdown]
# RDD Transformations

# %%
#convert name to uppercase
mapped_rdd=rdd.map(lambda x: (x[0].upper(),x[1]))
result=mapped_rdd.collect()
print(result)
# Out:
# [('ALICE', 27), ('BOB', 33), ('CHARLIE', 24), ('ALICE', 32)]

# %%
#filter records where age is greater than 30
filtered_rdd=rdd.filter(lambda x: x[1]> 30)
filtered_rdd.collect()
# Out:
# [('Bob', 33), ('Alice', 32)]

# %%
#sorting
sorted_rdd=rdd.sortBy(lambda x: x[1],ascending=False)
sorted_rdd.collect()
# Out:
# [('Bob', 33), ('Alice', 32), ('Alice', 27), ('Charlie', 24)]

# %%
import shutil
import os

out_path = "file:///D:/sparkapp/output.txt"  #better to use this format as spark does not understand windows directory style
local_path = "D:/sparkapp/output.txt"

# delete local folder if exists
shutil.rmtree(local_path, ignore_errors=True)

rdd.saveAsTextFile(out_path)

# %%
rdd_text=spark.sparkContext.textFile("output.txt")
rdd_text.collect()
# Out:
# ["('Alice', 27)", "('Bob', 33)", "('Charlie', 24)", "('Alice', 32)"]

# %% [markdown]
# DataFrame

# %%
#read txt file and count the number of occurance of words
#Using RDD
rdd=spark.sparkContext.textFile("long-doc.txt")
result_rdd=rdd.flatMap(lambda line: line.split(" ")) \
.map(lambda word: (word,1)) \
.reduceByKey(lambda a,b: a+b)\
.sortBy(lambda x: x[1],ascending=False)

result_rdd.take(10)
# Out:
# [('Lorem', 2000),
#  ('ipsum', 2000),
#  ('consectetur', 2000),
#  ('elit.', 2000),
#  ('dolor', 2000),
#  ('sit', 2000),
#  ('amet,', 2000),
#  ('adipiscing', 2000),
#  ('', 2),
#  ('sample', 2)]

# %%
from pyspark.sql.functions import desc

# %%
#using DataFrame
df=spark.read.text("long-doc.txt")

result_df=df.selectExpr("explode(split(value,' ')) as word") \
.groupBy("word").count().orderBy(desc("count"))

result_df.take(10)
# Out:
# [Row(word='sit', count=2000),
#  Row(word='consectetur', count=2000),
#  Row(word='dolor', count=2000),
#  Row(word='Lorem', count=2000),
#  Row(word='amet,', count=2000),
#  Row(word='ipsum', count=2000),
#  Row(word='elit.', count=2000),
#  Row(word='adipiscing', count=2000),
#  Row(word='sample', count=2),
#  Row(word='', count=2)]

# %% [markdown]
# Reading csv file from dataframe

# %%
# 6608 records

# %%
import pandas as pd

df = pd.read_csv("StudentperformanceFactors.csv")
df.head(10)
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
# 5             19          88               Medium              Medium
# 6             29          84               Medium                 Low
# 7             25          78                  Low                High
# 8             17          94               Medium                High
# 9             23          98               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
# 5                        Yes            8               89           Medium
# 6                        Yes            7               68              Low
# 7                        Yes            6               50           Medium
# 8                         No            6               80             High
# 9                        Yes            8               71           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
# 3             Yes                  1        Medium          Medium
# 4             Yes                  3        Medium            High
# 5             Yes                  3        Medium          Medium
# 6             Yes                  1           Low          Medium
# 7             Yes                  1          High            High
# 8             Yes                  0        Medium             Low
# 9             Yes                  0          High            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
# 5      Public       Positive                  3                    No
# 6     Private        Neutral                  2                    No
# 7      Public       Negative                  2                    No
# 8     Private        Neutral                  1                    No
# 9      Public       Positive                  5                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70
# 5             Postgraduate               Near    Male          71
# 6              High School           Moderate    Male          67
# 7              High School                Far    Male          66
# 8                  College               Near    Male          69
# 9              High School           Moderate    Male          72

# %%
path="StudentPerformanceFactors.csv"
df=spark.read.csv(path,header=True)

# %%
df.printSchema()

df.show(5)
# Out:
# root
#  |-- Hours_Studied: string (nullable = true)
#  |-- Attendance: string (nullable = true)
#  |-- Parental_Involvement: string (nullable = true)
#  |-- Access_to_Resources: string (nullable = true)
#  |-- Extracurricular_Activities: string (nullable = true)
#  |-- Sleep_Hours: string (nullable = true)
#  |-- Previous_Scores: string (nullable = true)
#  |-- Motivation_Level: string (nullable = true)
#  |-- Internet_Access: string (nullable = true)
#  |-- Tutoring_Sessions: string (nullable = true)
#  |-- Family_Income: string (nullable = true)
#  |-- Teacher_Quality: string (nullable = true)
#  |-- School_Type: string (nullable = true)
#  |-- Peer_Influence: string (nullable = true)
#  |-- Physical_Activity: string (nullable = true)
#  |-- Learning_Disabilities: string (nullable = true)
#  |-- Parental_Education_Level: string (nullable = true)
#  |-- Distance_from_Home: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Exam_Score: string (nullable = true)
#
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |Hours_Studied|Attendance|Parental_Involvement|Access_to_Resources|Extracurricular_Activities|Sleep_Hours|Previous_Scores|Motivation_Level|Internet_Access|Tutoring_Sessions|Family_Income|Teacher_Quality|School_Type|Peer_Influence|Physical_Activity|Learning_Disabilities|Parental_Education_Level|Distance_from_Home|Gender|Exam_Score|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |           23|        84|                 Low|               High|                        No|          7|             73|             Low|            Yes|                0|          Low|         Medium|     Public|      Positive|                3|                   No|             High School|              Near|  Male|        67|
# |           19|        64|                 Low|             Medium|                        No|          8|             59|             Low|            Yes|                2|       Medium|         Medium|     Public|      Negative|                4|                   No|                 College|          Moderate|Female|        61|
# |           24|        98|              Medium|             Medium|                       Yes|          7|             91|          Medium|            Yes|                2|       Medium|         Medium|     Public|       Neutral|                4|                   No|            Postgraduate|              Near|  Male|        74|
# |           29|        89|                 Low|             Medium|                       Yes|          8|             98|          Medium|            Yes|                1|       Medium|         Medium|     Public|      Negative|                4|                   No|             High School|          Moderate|  Male|        71|
# |           19|        92|              Medium|             Medium|                       Yes|          6|             65|          Medium|            Yes|                3|       Medium|           High|     Public|       Neutral|                4|                   No|                 College|              Near|Female|        70|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# only showing top 5 rows

# %%
#Every datatype is string which is not expected
from pyspark.sql.types import StructType,StructField,StringType,IntegerType,DoubleType

# %%
schema = StructType([
    StructField("Hours_Studied", IntegerType(), True),
    StructField("Attendance", IntegerType(), True),
    StructField("Parental_Involvement", StringType(), True),
    StructField("Access_to_Resources", StringType(), True),
    StructField("Extracurricular_Activities", StringType(), True),
    StructField("Sleep_Hours", IntegerType(), True),
    StructField("Previous_Scores", IntegerType(), True),
    StructField("Motivation_Level", StringType(), True),
    StructField("Internet_Access", StringType(), True),
    StructField("Tutoring_Sessions", IntegerType(), True),
    StructField("Family_Income", StringType(), True),
    StructField("Teacher_Quality", StringType(), True),
    StructField("School_Type", StringType(), True),
    StructField("Peer_Influence", StringType(), True),
    StructField("Physical_Activity", IntegerType(), True),
    StructField("Learning_Disabilities", StringType(), True),
    StructField("Parental_Education_Level", StringType(), True),
    StructField("Distance_from_Home", StringType(), True),
    StructField("Gender", StringType(), True),
    StructField("Exam_Score", IntegerType(), True)
])

# %%
df=spark.read.csv(path,header=True,schema=schema)

# %%
#again display with proper datatypes
df.printSchema()

df.show(5)
# Out:
# root
#  |-- Hours_Studied: integer (nullable = true)
#  |-- Attendance: integer (nullable = true)
#  |-- Parental_Involvement: string (nullable = true)
#  |-- Access_to_Resources: string (nullable = true)
#  |-- Extracurricular_Activities: string (nullable = true)
#  |-- Sleep_Hours: integer (nullable = true)
#  |-- Previous_Scores: integer (nullable = true)
#  |-- Motivation_Level: string (nullable = true)
#  |-- Internet_Access: string (nullable = true)
#  |-- Tutoring_Sessions: integer (nullable = true)
#  |-- Family_Income: string (nullable = true)
#  |-- Teacher_Quality: string (nullable = true)
#  |-- School_Type: string (nullable = true)
#  |-- Peer_Influence: string (nullable = true)
#  |-- Physical_Activity: integer (nullable = true)
#  |-- Learning_Disabilities: string (nullable = true)
#  |-- Parental_Education_Level: string (nullable = true)
#  |-- Distance_from_Home: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Exam_Score: integer (nullable = true)
#
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |Hours_Studied|Attendance|Parental_Involvement|Access_to_Resources|Extracurricular_Activities|Sleep_Hours|Previous_Scores|Motivation_Level|Internet_Access|Tutoring_Sessions|Family_Income|Teacher_Quality|School_Type|Peer_Influence|Physical_Activity|Learning_Disabilities|Parental_Education_Level|Distance_from_Home|Gender|Exam_Score|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |           23|        84|                 Low|               High|                        No|          7|             73|             Low|            Yes|                0|          Low|         Medium|     Public|      Positive|                3|                   No|             High School|              Near|  Male|        67|
# |           19|        64|                 Low|             Medium|                        No|          8|             59|             Low|            Yes|                2|       Medium|         Medium|     Public|      Negative|                4|                   No|                 College|          Moderate|Female|        61|
# |           24|        98|              Medium|             Medium|                       Yes|          7|             91|          Medium|            Yes|                2|       Medium|         Medium|     Public|       Neutral|                4|                   No|            Postgraduate|              Near|  Male|        74|
# |           29|        89|                 Low|             Medium|                       Yes|          8|             98|          Medium|            Yes|                1|       Medium|         Medium|     Public|      Negative|                4|                   No|             High School|          Moderate|  Male|        71|
# |           19|        92|              Medium|             Medium|                       Yes|          6|             65|          Medium|            Yes|                3|       Medium|           High|     Public|       Neutral|                4|                   No|                 College|              Near|Female|        70|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# only showing top 5 rows

# %%
#automatically guess the data type of the columns
df=spark.read.csv(path,header=True,inferSchema=True)
df.printSchema()
df.show(5)
# Out:
# root
#  |-- Hours_Studied: integer (nullable = true)
#  |-- Attendance: integer (nullable = true)
#  |-- Parental_Involvement: string (nullable = true)
#  |-- Access_to_Resources: string (nullable = true)
#  |-- Extracurricular_Activities: string (nullable = true)
#  |-- Sleep_Hours: integer (nullable = true)
#  |-- Previous_Scores: integer (nullable = true)
#  |-- Motivation_Level: string (nullable = true)
#  |-- Internet_Access: string (nullable = true)
#  |-- Tutoring_Sessions: integer (nullable = true)
#  |-- Family_Income: string (nullable = true)
#  |-- Teacher_Quality: string (nullable = true)
#  |-- School_Type: string (nullable = true)
#  |-- Peer_Influence: string (nullable = true)
#  |-- Physical_Activity: integer (nullable = true)
#  |-- Learning_Disabilities: string (nullable = true)
#  |-- Parental_Education_Level: string (nullable = true)
#  |-- Distance_from_Home: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Exam_Score: integer (nullable = true)
#
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |Hours_Studied|Attendance|Parental_Involvement|Access_to_Resources|Extracurricular_Activities|Sleep_Hours|Previous_Scores|Motivation_Level|Internet_Access|Tutoring_Sessions|Family_Income|Teacher_Quality|School_Type|Peer_Influence|Physical_Activity|Learning_Disabilities|Parental_Education_Level|Distance_from_Home|Gender|Exam_Score|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |           23|        84|                 Low|               High|                        No|          7|             73|             Low|            Yes|                0|          Low|         Medium|     Public|      Positive|                3|                   No|             High School|              Near|  Male|        67|
# |           19|        64|                 Low|             Medium|                        No|          8|             59|             Low|            Yes|                2|       Medium|         Medium|     Public|      Negative|                4|                   No|                 College|          Moderate|Female|        61|
# |           24|        98|              Medium|             Medium|                       Yes|          7|             91|          Medium|            Yes|                2|       Medium|         Medium|     Public|       Neutral|                4|                   No|            Postgraduate|              Near|  Male|        74|
# |           29|        89|                 Low|             Medium|                       Yes|          8|             98|          Medium|            Yes|                1|       Medium|         Medium|     Public|      Negative|                4|                   No|             High School|          Moderate|  Male|        71|
# |           19|        92|              Medium|             Medium|                       Yes|          6|             65|          Medium|            Yes|                3|       Medium|           High|     Public|       Neutral|                4|                   No|                 College|              Near|Female|        70|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# only showing top 5 rows

# %%
selected_columns=df.select("Sleep_Hours","Attendance")
selected_columns.show(10)
# Out:
# +-----------+----------+
# |Sleep_Hours|Attendance|
# +-----------+----------+
# |          7|        84|
# |          8|        64|
# |          7|        98|
# |          8|        89|
# |          6|        92|
# |          8|        88|
# |          7|        84|
# |          6|        78|
# |          6|        94|
# |          8|        98|
# +-----------+----------+
# only showing top 10 rows

# %%
#filtering based on condition on columns
filtered_data=df.filter(df.Hours_Studied >20)
print(filtered_data.count())
filtered_data.show(10)
# Out:
# 3063
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |Hours_Studied|Attendance|Parental_Involvement|Access_to_Resources|Extracurricular_Activities|Sleep_Hours|Previous_Scores|Motivation_Level|Internet_Access|Tutoring_Sessions|Family_Income|Teacher_Quality|School_Type|Peer_Influence|Physical_Activity|Learning_Disabilities|Parental_Education_Level|Distance_from_Home|Gender|Exam_Score|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |           23|        84|                 Low|               High|                        No|          7|             73|             Low|            Yes|                0|          Low|         Medium|     Public|      Positive|                3|                   No|             High School|              Near|  Male|        67|
# |           24|        98|              Medium|             Medium|                       Yes|          7|             91|          Medium|            Yes|                2|       Medium|         Medium|     Public|       Neutral|                4|                   No|            Postgraduate|              Near|  Male|        74|
# |           29|        89|                 Low|             Medium|                       Yes|          8|             98|          Medium|            Yes|                1|       Medium|         Medium|     Public|      Negative|                4|                   No|             High School|          Moderate|  Male|        71|
# |           29|        84|              Medium|                Low|                       Yes|          7|             68|             Low|            Yes|                1|          Low|         Medium|    Private|       Neutral|                2|                   No|             High School|          Moderate|  Male|        67|
# |           25|        78|                 Low|               High|                       Yes|          6|             50|          Medium|            Yes|                1|         High|           High|     Public|      Negative|                2|                   No|             High School|               Far|  Male|        66|
# |           23|        98|              Medium|             Medium|                       Yes|          8|             71|          Medium|            Yes|                0|         High|           High|     Public|      Positive|                5|                   No|             High School|          Moderate|  Male|        72|
# |           21|        83|              Medium|             Medium|                       Yes|          8|             97|             Low|            Yes|                2|       Medium|         Medium|     Public|      Positive|                4|                   No|             High School|              Near|  Male|        70|
# |           22|        70|                 Low|             Medium|                       Yes|          6|             82|          Medium|            Yes|                1|          Low|           High|     Public|       Neutral|                3|                   No|             High School|              Near|Female|        65|
# |           29|        78|              Medium|             Medium|                        No|          5|             99|            High|            Yes|                0|         High|         Medium|     Public|      Negative|                1|                   No|             High School|          Moderate|Female|        69|
# |           21|        62|                High|                Low|                       Yes|          6|             54|            High|            Yes|                0|         High|           High|     Public|      Positive|                3|                   No|            Postgraduate|               Far|  Male|        64|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# only showing top 10 rows

# %%
#sorting
sorted_data=df.orderBy("Exam_Score")
sorted_data.show(10)
# Out:
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |Hours_Studied|Attendance|Parental_Involvement|Access_to_Resources|Extracurricular_Activities|Sleep_Hours|Previous_Scores|Motivation_Level|Internet_Access|Tutoring_Sessions|Family_Income|Teacher_Quality|School_Type|Peer_Influence|Physical_Activity|Learning_Disabilities|Parental_Education_Level|Distance_from_Home|Gender|Exam_Score|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |            3|        62|              Medium|                Low|                        No|          6|             67|          Medium|            Yes|                1|          Low|         Medium|     Public|      Negative|                3|                   No|             High School|              Near|  Male|        55|
# |            5|        65|                 Low|               High|                        No|          7|             71|          Medium|            Yes|                0|          Low|         Medium|    Private|      Negative|                2|                   No|                 College|               Far|  Male|        56|
# |            7|        66|                High|                Low|                       Yes|          8|             68|            High|            Yes|                0|          Low|         Medium|     Public|      Negative|                2|                  Yes|                 College|          Moderate|  Male|        57|
# |           14|        67|                 Low|                Low|                       Yes|          7|             66|             Low|            Yes|                0|          Low|         Medium|     Public|       Neutral|                4|                   No|             High School|               Far|Female|        57|
# |            9|        64|              Medium|                Low|                       Yes|         10|             68|             Low|            Yes|                0|       Medium|         Medium|    Private|      Negative|                3|                   No|             High School|              Near|  Male|        57|
# |            3|        60|              Medium|                Low|                       Yes|          6|             78|             Low|            Yes|                1|          Low|         Medium|     Public|      Positive|                1|                   No|            Postgraduate|              Near|Female|        57|
# |            4|        62|              Medium|             Medium|                        No|          6|             78|            High|            Yes|                3|         High|           NULL|     Public|       Neutral|                2|                   No|             High School|               Far|Female|        58|
# |            4|        69|              Medium|                Low|                        No|          9|             93|             Low|             No|                2|       Medium|           High|    Private|      Negative|                3|                   No|             High School|          Moderate|Female|        58|
# |           14|        61|              Medium|             Medium|                        No|          5|             82|             Low|             No|                0|          Low|         Medium|     Public|       Neutral|                0|                   No|             High School|              Near|Female|        58|
# |            2|        67|              Medium|             Medium|                        No|          6|             73|             Low|            Yes|                1|          Low|         Medium|    Private|      Positive|                2|                   No|                 College|          Moderate|  Male|        58|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# only showing top 10 rows

# %%
#distinct
distnct_rows=df.select("Teacher_Quality").distinct()
distnct_rows.show()
# Out:
# +---------------+
# |Teacher_Quality|
# +---------------+
# |           High|
# |            Low|
# |         Medium|
# |           NULL|
# +---------------+

# %%
dropped_columns=df.drop("Gender")
dropped_columns.show(10)
# Out:
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+----------+
# |Hours_Studied|Attendance|Parental_Involvement|Access_to_Resources|Extracurricular_Activities|Sleep_Hours|Previous_Scores|Motivation_Level|Internet_Access|Tutoring_Sessions|Family_Income|Teacher_Quality|School_Type|Peer_Influence|Physical_Activity|Learning_Disabilities|Parental_Education_Level|Distance_from_Home|Exam_Score|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+----------+
# |           23|        84|                 Low|               High|                        No|          7|             73|             Low|            Yes|                0|          Low|         Medium|     Public|      Positive|                3|                   No|             High School|              Near|        67|
# |           19|        64|                 Low|             Medium|                        No|          8|             59|             Low|            Yes|                2|       Medium|         Medium|     Public|      Negative|                4|                   No|                 College|          Moderate|        61|
# |           24|        98|              Medium|             Medium|                       Yes|          7|             91|          Medium|            Yes|                2|       Medium|         Medium|     Public|       Neutral|                4|                   No|            Postgraduate|              Near|        74|
# |           29|        89|                 Low|             Medium|                       Yes|          8|             98|          Medium|            Yes|                1|       Medium|         Medium|     Public|      Negative|                4|                   No|             High School|          Moderate|        71|
# |           19|        92|              Medium|             Medium|                       Yes|          6|             65|          Medium|            Yes|                3|       Medium|           High|     Public|       Neutral|                4|                   No|                 College|              Near|        70|
# |           19|        88|              Medium|             Medium|                       Yes|          8|             89|          Medium|            Yes|                3|       Medium|         Medium|     Public|      Positive|                3|                   No|            Postgraduate|              Near|        71|
# |           29|        84|              Medium|                Low|                       Yes|          7|             68|             Low|            Yes|                1|          Low|         Medium|    Private|       Neutral|                2|                   No|             High School|          Moderate|        67|
# |           25|        78|                 Low|               High|                       Yes|          6|             50|          Medium|            Yes|                1|         High|           High|     Public|      Negative|                2|                   No|             High School|               Far|        66|
# |           17|        94|              Medium|               High|                        No|          6|             80|            High|            Yes|                0|       Medium|            Low|    Private|       Neutral|                1|                   No|                 College|              Near|        69|
# |           23|        98|              Medium|             Medium|                       Yes|          8|             71|          Medium|            Yes|                0|         High|           High|     Public|      Positive|                5|                   No|             High School|          Moderate|        72|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+----------+
# only showing top 10 rows

# %%
#creating new column
new_col=df.withColumn("NEW_SCORE",df.Previous_Scores+df.Exam_Score)
new_col.show(10)
# Out:
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+---------+
# |Hours_Studied|Attendance|Parental_Involvement|Access_to_Resources|Extracurricular_Activities|Sleep_Hours|Previous_Scores|Motivation_Level|Internet_Access|Tutoring_Sessions|Family_Income|Teacher_Quality|School_Type|Peer_Influence|Physical_Activity|Learning_Disabilities|Parental_Education_Level|Distance_from_Home|Gender|Exam_Score|NEW_SCORE|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+---------+
# |           23|        84|                 Low|               High|                        No|          7|             73|             Low|            Yes|                0|          Low|         Medium|     Public|      Positive|                3|                   No|             High School|              Near|  Male|        67|      140|
# |           19|        64|                 Low|             Medium|                        No|          8|             59|             Low|            Yes|                2|       Medium|         Medium|     Public|      Negative|                4|                   No|                 College|          Moderate|Female|        61|      120|
# |           24|        98|              Medium|             Medium|                       Yes|          7|             91|          Medium|            Yes|                2|       Medium|         Medium|     Public|       Neutral|                4|                   No|            Postgraduate|              Near|  Male|        74|      165|
# |           29|        89|                 Low|             Medium|                       Yes|          8|             98|          Medium|            Yes|                1|       Medium|         Medium|     Public|      Negative|                4|                   No|             High School|          Moderate|  Male|        71|      169|
# |           19|        92|              Medium|             Medium|                       Yes|          6|             65|          Medium|            Yes|                3|       Medium|           High|     Public|       Neutral|                4|                   No|                 College|              Near|Female|        70|      135|
# |           19|        88|              Medium|             Medium|                       Yes|          8|             89|          Medium|            Yes|                3|       Medium|         Medium|     Public|      Positive|                3|                   No|            Postgraduate|              Near|  Male|        71|      160|
# |           29|        84|              Medium|                Low|                       Yes|          7|             68|             Low|            Yes|                1|          Low|         Medium|    Private|       Neutral|                2|                   No|             High School|          Moderate|  Male|        67|      135|
# |           25|        78|                 Low|               High|                       Yes|          6|             50|          Medium|            Yes|                1|         High|           High|     Public|      Negative|                2|                   No|             High School|               Far|  Male|        66|      116|
# |           17|        94|              Medium|               High|                        No|          6|             80|            High|            Yes|                0|       Medium|            Low|    Private|       Neutral|                1|                   No|                 College|              Near|  Male|        69|      149|
# |           23|        98|              Medium|             Medium|                       Yes|          8|             71|          Medium|            Yes|                0|         High|           High|     Public|      Positive|                5|                   No|             High School|          Moderate|  Male|        72|      143|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+---------+
# only showing top 10 rows

# %%
#For SQL, register dataframe as a temporary table
df.createOrReplaceTempView("my_table")
result= spark.sql("SELECT * FROM my_table WHERE Hours_Studied>20")
result.show()
# Out:
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |Hours_Studied|Attendance|Parental_Involvement|Access_to_Resources|Extracurricular_Activities|Sleep_Hours|Previous_Scores|Motivation_Level|Internet_Access|Tutoring_Sessions|Family_Income|Teacher_Quality|School_Type|Peer_Influence|Physical_Activity|Learning_Disabilities|Parental_Education_Level|Distance_from_Home|Gender|Exam_Score|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# |           23|        84|                 Low|               High|                        No|          7|             73|             Low|            Yes|                0|          Low|         Medium|     Public|      Positive|                3|                   No|             High School|              Near|  Male|        67|
# |           24|        98|              Medium|             Medium|                       Yes|          7|             91|          Medium|            Yes|                2|       Medium|         Medium|     Public|       Neutral|                4|                   No|            Postgraduate|              Near|  Male|        74|
# |           29|        89|                 Low|             Medium|                       Yes|          8|             98|          Medium|            Yes|                1|       Medium|         Medium|     Public|      Negative|                4|                   No|             High School|          Moderate|  Male|        71|
# |           29|        84|              Medium|                Low|                       Yes|          7|             68|             Low|            Yes|                1|          Low|         Medium|    Private|       Neutral|                2|                   No|             High School|          Moderate|  Male|        67|
# |           25|        78|                 Low|               High|                       Yes|          6|             50|          Medium|            Yes|                1|         High|           High|     Public|      Negative|                2|                   No|             High School|               Far|  Male|        66|
# |           23|        98|              Medium|             Medium|                       Yes|          8|             71|          Medium|            Yes|                0|         High|           High|     Public|      Positive|                5|                   No|             High School|          Moderate|  Male|        72|
# |           21|        83|              Medium|             Medium|                       Yes|          8|             97|             Low|            Yes|                2|       Medium|         Medium|     Public|      Positive|                4|                   No|             High School|              Near|  Male|        70|
# |           22|        70|                 Low|             Medium|                       Yes|          6|             82|          Medium|            Yes|                1|          Low|           High|     Public|       Neutral|                3|                   No|             High School|              Near|Female|        65|
# |           29|        78|              Medium|             Medium|                        No|          5|             99|            High|            Yes|                0|         High|         Medium|     Public|      Negative|                1|                   No|             High School|          Moderate|Female|        69|
# |           21|        62|                High|                Low|                       Yes|          6|             54|            High|            Yes|                0|         High|           High|     Public|      Positive|                3|                   No|            Postgraduate|               Far|  Male|        64|
# |           22|        83|                High|               High|                       Yes|          6|             94|          Medium|            Yes|                0|         High|         Medium|     Public|       Neutral|                2|                   No|                 College|          Moderate|  Male|        71|
# |           31|        70|              Medium|               High|                       Yes|          7|             66|          Medium|            Yes|                1|         High|         Medium|     Public|      Negative|                3|                   No|                 College|              Near|  Male|        69|
# |           25|        65|                High|             Medium|                        No|          5|             90|          Medium|            Yes|                2|       Medium|         Medium|     Public|      Positive|                3|                   No|                 College|          Moderate|Female|        68|
# |           21|        65|              Medium|                Low|                       Yes|          7|             91|             Low|            Yes|                2|       Medium|           High|     Public|      Positive|                3|                   No|             High School|               Far|Female|        64|
# |           21|        65|                 Low|             Medium|                       Yes|          6|             98|             Low|            Yes|                1|       Medium|           High|     Public|      Negative|                4|                   No|             High School|              Near|  Male|        64|
# |           24|        68|                High|             Medium|                        No|          8|             56|             Low|            Yes|                3|         High|           High|     Public|       Neutral|                1|                   No|                 College|              Near|  Male|        67|
# |           21|        84|              Medium|             Medium|                       Yes|          6|             52|             Low|            Yes|                1|       Medium|           High|     Public|       Neutral|                2|                  Yes|                 College|               Far|Female|        65|
# |           26|        61|              Medium|                Low|                       Yes|          6|             70|          Medium|            Yes|                2|          Low|         Medium|     Public|      Positive|                3|                   No|             High School|          Moderate|Female|        64|
# |           22|        86|                 Low|             Medium|                       Yes|          7|             72|             Low|            Yes|                3|          Low|           High|     Public|      Positive|                2|                   No|             High School|          Moderate|  Male|        68|
# |           22|        71|                 Low|             Medium|                       Yes|          7|             65|             Low|            Yes|                1|       Medium|            Low|     Public|      Positive|                4|                   No|                 College|          Moderate|  Male|        64|
# +-------------+----------+--------------------+-------------------+--------------------------+-----------+---------------+----------------+---------------+-----------------+-------------+---------------+-----------+--------------+-----------------+---------------------+------------------------+------------------+------+----------+
# only showing top 20 rows

# %%
avg_attendance_by_gender=spark.sql("SELECT Gender,AVG(Attendance) as avg_attendance FROM my_table GROUP BY Gender")
avg_attendance_by_gender.show()
# Out:
# +------+-----------------+
# |Gender|   avg_attendance|
# +------+-----------------+
# |Female|79.86895810955961|
# |  Male|80.05689564761406|
# +------+-----------------+

# %%
spark.stop()
